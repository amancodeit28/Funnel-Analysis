# %% [markdown]
# Funnel Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# Corporate Styling

# %%
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')
print("Everything is fine")
# Out:
# Everything is fine

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv(r"C:\Users\93sha\Downloads\funnel_analysis_data.csv")
df.head(10)
# Out:
#     User_ID Session_ID        Event            Timestamp   Device Region  \
# 0  USR00001   SES00001       Browse  2025-10-28 07:33:50  Desktop   West
# 1  USR00001   SES00001  Add to Cart  2025-10-28 07:36:50   Tablet   East
# 2  USR00001   SES00001     Checkout  2025-10-28 07:40:50   Mobile   West
# 3  USR00002   SES00002       Browse  2025-10-19 09:15:10  Desktop   East
# 4  USR00002   SES00002  Add to Cart  2025-10-19 09:18:10   Mobile   West
# 5  USR00002   SES00002     Checkout  2025-10-19 09:23:10  Desktop  North
# 6  USR00002   SES00002     Purchase  2025-10-19 09:27:10   Mobile  North
# 7  USR00003   SES00003       Browse  2025-10-12 02:19:00  Desktop   East
# 8  USR00003   SES00003  Add to Cart  2025-10-12 02:22:00   Tablet  South
# 9  USR00003   SES00003     Checkout  2025-10-12 02:26:00  Desktop   West
#
#         Channel Product_Category  Revenue Bounce_Flag
# 0       Organic             Home     0.00         Yes
# 1  Social Media           Beauty     0.00         Yes
# 2         Email           Beauty     0.00         Yes
# 3         Email      Electronics     0.00          No
# 4  Social Media          Fashion     0.00          No
# 5  Social Media          Fashion     0.00          No
# 6    Google Ads           Sports   448.18          No
# 7    Google Ads           Beauty     0.00          No
# 8  Social Media           Beauty     0.00          No
# 9    Google Ads           Sports     0.00          No

# %%
## Basic Analysis
df.tail(10)
# Out:
#         User_ID Session_ID        Event            Timestamp   Device Region  \
# 21653  USR09996   SES09996     Purchase  2025-10-24 13:55:03   Mobile  North
# 21654  USR09997   SES09997       Browse  2025-10-28 02:53:54   Mobile  South
# 21655  USR09998   SES09998       Browse  2025-10-09 12:04:15   Tablet   East
# 21656  USR09998   SES09998  Add to Cart  2025-10-09 12:06:15  Desktop  South
# 21657  USR09998   SES09998     Checkout  2025-10-09 12:08:15   Tablet   East
# 21658  USR09999   SES09999       Browse  2025-10-03 17:22:58  Desktop  South
# 21659  USR09999   SES09999  Add to Cart  2025-10-03 17:26:58   Tablet   West
# 21660  USR09999   SES09999     Checkout  2025-10-03 17:29:58   Mobile  North
# 21661  USR09999   SES09999     Purchase  2025-10-03 17:34:58   Mobile   East
# 21662  USR10000   SES10000       Browse  2025-10-15 20:32:43   Mobile  South
#
#             Channel Product_Category  Revenue Bounce_Flag
# 21653  Social Media          Fashion  1997.47          No
# 21654    Google Ads             Home     0.00         Yes
# 21655  Social Media           Beauty     0.00         Yes
# 21656         Email             Home     0.00         Yes
# 21657         Email          Fashion     0.00         Yes
# 21658    Google Ads      Electronics     0.00          No
# 21659  Social Media          Fashion     0.00          No
# 21660         Email          Fashion     0.00          No
# 21661         Email          Fashion   960.65          No
# 21662    Google Ads           Beauty     0.00         Yes

# %%
df.describe()
# Out:
#             Revenue
# count  21663.000000
# mean      54.304841
# std      262.692471
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max     1998.510000

# %%
df.shape
# Out:
# (21663, 10)

# %%
## Timestamp column must be in the date time type
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
print(df.dtypes)
# Out:
# User_ID                     object
# Session_ID                  object
# Event                       object
# Timestamp           datetime64[ns]
# Device                      object
# Region                      object
# Channel                     object
# Product_Category            object
# Revenue                    float64
# Bounce_Flag                 object
# dtype: object

# %%
## Information about all columns
df.describe(include="object")
# Out:
#          User_ID Session_ID   Event  Device Region     Channel  \
# count      21663      21663   21663   21663  21663       21663
# unique     10000      10000       4       3      4           4
# top     USR07731   SES07731  Browse  Tablet   West  Google Ads
# freq           4          4   10000    7237   5462        5435
#
#        Product_Category Bounce_Flag
# count             21663       21663
# unique                5           2
# top         Electronics         Yes
# freq               4405       17343

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21663 entries, 0 to 21662
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           21663 non-null  object
#  1   Session_ID        21663 non-null  object
#  2   Event             21663 non-null  object
#  3   Timestamp         21663 non-null  datetime64[ns]
#  4   Device            21663 non-null  object
#  5   Region            21663 non-null  object
#  6   Channel           21663 non-null  object
#  7   Product_Category  21663 non-null  object
#  8   Revenue           21663 non-null  float64
#  9   Bounce_Flag       21663 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#                            Timestamp       Revenue
# count                          21663  21663.000000
# mean   2025-10-16 19:56:22.920740608     54.304841
# min              2025-10-01 19:30:17      0.000000
# 25%              2025-10-09 08:31:38      0.000000
# 50%              2025-10-16 19:47:21      0.000000
# 75%              2025-10-24 08:13:17      0.000000
# max              2025-10-31 19:25:15   1998.510000
# std                              NaN    262.692471

# %%
pd.set_option("display.max_rows", None)

# %%
df.head()
# Out:
#     User_ID Session_ID        Event           Timestamp   Device Region  \
# 0  USR00001   SES00001       Browse 2025-10-28 07:33:50  Desktop   West
# 1  USR00001   SES00001  Add to Cart 2025-10-28 07:36:50   Tablet   East
# 2  USR00001   SES00001     Checkout 2025-10-28 07:40:50   Mobile   West
# 3  USR00002   SES00002       Browse 2025-10-19 09:15:10  Desktop   East
# 4  USR00002   SES00002  Add to Cart 2025-10-19 09:18:10   Mobile   West
#
#         Channel Product_Category  Revenue Bounce_Flag
# 0       Organic             Home      0.0         Yes
# 1  Social Media           Beauty      0.0         Yes
# 2         Email           Beauty      0.0         Yes
# 3         Email      Electronics      0.0          No
# 4  Social Media          Fashion      0.0          No

# %% [markdown]
# Data Preprocessing and Cleaning

# %%
## check for NULL VALUES if present in a Null values 
df.isnull().sum()

print("\n")

## Check for duplicate values
df.duplicated().sum()

print("\n")

## Check for unique values
df.nunique()
# Out:
# User_ID             10000
# Session_ID          10000
# Event                   4
# Timestamp           21564
# Device                  3
# Region                  4
# Channel                 4
# Product_Category        5
# Revenue              1078
# Bounce_Flag             2
# dtype: int64

# %%
## Now fixing the data and extracting time based data 
## Now we can analyze the data more efficiently

df['Date'] = df['Timestamp'].dt.date
df['DayOfWeek'] = df['Timestamp'].dt.day_name()
df['Hour'] = df['Timestamp'].dt.hour
df['WeekNumber'] = df['Timestamp'].dt.isocalendar().week

# %%
df.head(10)
# Out:
#     User_ID Session_ID        Event           Timestamp   Device Region  \
# 0  USR00001   SES00001       Browse 2025-10-28 07:33:50  Desktop   West
# 1  USR00001   SES00001  Add to Cart 2025-10-28 07:36:50   Tablet   East
# 2  USR00001   SES00001     Checkout 2025-10-28 07:40:50   Mobile   West
# 3  USR00002   SES00002       Browse 2025-10-19 09:15:10  Desktop   East
# 4  USR00002   SES00002  Add to Cart 2025-10-19 09:18:10   Mobile   West
# 5  USR00002   SES00002     Checkout 2025-10-19 09:23:10  Desktop  North
# 6  USR00002   SES00002     Purchase 2025-10-19 09:27:10   Mobile  North
# 7  USR00003   SES00003       Browse 2025-10-12 02:19:00  Desktop   East
# 8  USR00003   SES00003  Add to Cart 2025-10-12 02:22:00   Tablet  South
# 9  USR00003   SES00003     Checkout 2025-10-12 02:26:00  Desktop   West
#
#         Channel Product_Category  Revenue Bounce_Flag        Date DayOfWeek  \
# 0       Organic             Home     0.00         Yes  2025-10-28   Tuesday
# 1  Social Media           Beauty     0.00         Yes  2025-10-28   Tuesday
# 2         Email           Beauty     0.00         Yes  2025-10-28   Tuesday
# 3         Email      Electronics     0.00          No  2025-10-19    Sunday
# 4  Social Media          Fashion     0.00          No  2025-10-19    Sunday
# 5  Social Media          Fashion     0.00          No  2025-10-19    Sunday
# 6    Google Ads           Sports   448.18          No  2025-10-19    Sunday
# 7    Google Ads           Beauty     0.00          No  2025-10-12    Sunday
# 8  Social Media           Beauty     0.00          No  2025-10-12    Sunday
# 9    Google Ads           Sports     0.00          No  2025-10-12    Sunday
#
#    Hour  WeekNumber
# 0     7          44
# 1     7          44
# 2     7          44
# 3     9          42
# 4     9          42
# 5     9          42
# 6     9          42
# 7     2          41
# 8     2          41
# 9     2          41

# %%
df["Event_Sequence"] = df.groupby("Session_ID").cumcount() + 1

# %%
df.head()
# Out:
#     User_ID Session_ID        Event           Timestamp   Device Region  \
# 0  USR00001   SES00001       Browse 2025-10-28 07:33:50  Desktop   West
# 1  USR00001   SES00001  Add to Cart 2025-10-28 07:36:50   Tablet   East
# 2  USR00001   SES00001     Checkout 2025-10-28 07:40:50   Mobile   West
# 3  USR00002   SES00002       Browse 2025-10-19 09:15:10  Desktop   East
# 4  USR00002   SES00002  Add to Cart 2025-10-19 09:18:10   Mobile   West
#
#         Channel Product_Category  Revenue Bounce_Flag        Date DayOfWeek  \
# 0       Organic             Home      0.0         Yes  2025-10-28   Tuesday
# 1  Social Media           Beauty      0.0         Yes  2025-10-28   Tuesday
# 2         Email           Beauty      0.0         Yes  2025-10-28   Tuesday
# 3         Email      Electronics      0.0          No  2025-10-19    Sunday
# 4  Social Media          Fashion      0.0          No  2025-10-19    Sunday
#
#    Hour  WeekNumber  Event_Sequence
# 0     7          44               1
# 1     7          44               2
# 2     7          44               3
# 3     9          42               1
# 4     9          42               2

# %%
## To basically find the unique values for userID and session
print(f"Total User ID {df["User_ID"].nunique()}")
print(f"Total Session ID {df["Session_ID"].nunique()}")
print("\n")
print(f"\n Date Range {df["Date"].min()} to {df["Date"].max()}")
# Out:
# Total User ID 10000
# Total Session ID 10000
#
#
#
#  Date Range 2025-10-01 to 2025-10-31

# %% [markdown]
# ## Funnel Stage Defination and Session-Level Aggregation

# %%
## Define funnel stages in order
funnel_stages = ["Browse", "Add to cart", "Checkout", "Purchase"]

session_summary = df.groupby("Session_ID").agg({
    "User_ID": "first",
    "Timestamp": ["min", "max"],
    "Event": lambda x: list(x),
    "Device": "first",
    "Region": "first",
    "Channel": "first",
    "Product_Category": "first",
    "Revenue": "max",   # or "sum"
    "Bounce_Flag": "first"
}).reset_index()

session_summary.columns = [
    "Session_ID", "User_ID", "Session_Start", "Session_End",
    "Event_Sequence", "Device", "Region", "Channel",
    "Product_Category", "Revenue", "Bounce_Flag"
]

session_summary["Session_Duration_Min"] = (
    session_summary["Session_End"] - session_summary["Session_Start"]
).dt.total_seconds() / 60

def get_max_funnel_stage(events):
    stage_values = {stage: i for i, stage in enumerate(funnel_stages)}
    max_stage_index = -1
    for event in events:
        if event in stage_values and stage_values[event] > max_stage_index:
            max_stage_index = stage_values[event]
    return funnel_stages[max_stage_index] if max_stage_index != -1 else "Browse"

session_summary["Max_Funnel_Stage"] = (
    session_summary["Event_Sequence"].apply(get_max_funnel_stage)
)

print("Session Summary Created:")
display(session_summary.head(10))
# Out:
# Session Summary Created:
#   Session_ID   User_ID       Session_Start         Session_End  \
# 0   SES00001  USR00001 2025-10-28 07:33:50 2025-10-28 07:40:50
# 1   SES00002  USR00002 2025-10-19 09:15:10 2025-10-19 09:27:10
# 2   SES00003  USR00003 2025-10-12 02:19:00 2025-10-12 02:29:00
# 3   SES00004  USR00004 2025-10-05 17:55:48 2025-10-05 17:55:48
# 4   SES00005  USR00005 2025-10-19 12:35:49 2025-10-19 12:37:49
# 5   SES00006  USR00006 2025-10-06 13:20:53 2025-10-06 13:20:53
# 6   SES00007  USR00007 2025-10-20 15:23:11 2025-10-20 15:23:11
# 7   SES00008  USR00008 2025-10-13 12:59:29 2025-10-13 13:10:29
# 8   SES00009  USR00009 2025-10-17 10:27:10 2025-10-17 10:30:10
# 9   SES00010  USR00010 2025-10-30 17:23:31 2025-10-30 17:23:31
#
#                               Event_Sequence   Device Region       Channel  \
# 0            [Browse, Add to Cart, Checkout]  Desktop   West       Organic
# 1  [Browse, Add to Cart, Checkout, Purchase]  Desktop   East         Email
# 2  [Browse, Add to Cart, Checkout, Purchase]  Desktop   East    Google Ads
# 3                                   [Browse]   Tablet   West  Social Media
# 4                      [Browse, Add to Cart]   Tablet   West    Google Ads
# 5                                   [Browse]   Tablet  North         Email
# 6                                   [Browse]   Mobile  South    Google Ads
# 7  [Browse, Add to Cart, Checkout, Purchase]  Desktop   West    Google Ads
# 8                      [Browse, Add to Cart]   Tablet  South       Organic
# 9                                   [Browse]  Desktop   West         Email
#
#   Product_Category  Revenue Bounce_Flag  Session_Duration_Min Max_Funnel_Stage
# 0             Home     0.00         Yes                   7.0         Checkout
# 1      Electronics   448.18          No                  12.0         Purchase
# 2           Beauty  1437.19          No                  10.0         Purchase
# 3             Home     0.00         Yes                   0.0           Browse
# 4      Electronics     0.00         Yes                   2.0           Browse
# 5           Beauty     0.00         Yes                   0.0           Browse
# 6             Home     0.00         Yes                   0.0           Browse
# 7           Beauty   304.30          No                  11.0         Purchase
# 8          Fashion     0.00         Yes                   3.0           Browse
# 9           Sports     0.00         Yes                   0.0           Browse

# %% [raw]
# ## Overall Funnel Analysis

# %%
## Calculate Overall funnel metrics
funnel_metrics = []
for i, stage in enumerate(funnel_stages):
    if i == 0:
        ## for Browse stage, count all sessions
        count = len(session_summary)
    else:
        ## for other stages, count sessions that reached at least this stage
        count = len(session_summary[session_summary["Max_Funnel_Stage"].isin(funnel_stages[i:])])

    funnel_metrics.append({
        "Stage": stage,
        "Sessions": count,
        "Stage_Order": i
    })

funnel_df = pd.DataFrame(funnel_metrics)

## Calculate conversion rates
funnel_df["Conversion_Rate"] = (funnel_df["Sessions"] / funnel_df["Sessions"].iloc[0] * 100).round(2)
funnel_df["Drop_Off_Rate"] = (1 - funnel_df["Sessions"] / funnel_df["Sessions"].shift(1)) * 100
funnel_df.loc[0, "Drop_Off_Rate"] = 0
funnel_df["Drop_Off_Rate"] = funnel_df["Drop_Off_Rate"].round(2)

print("Overall Funnel Analysis : ")
display(funnel_df)
# Out:
# Overall Funnel Analysis :
#          Stage  Sessions  Stage_Order  Conversion_Rate  Drop_Off_Rate
# 0       Browse     10000            0           100.00           0.00
# 1  Add to cart      3524            1            35.24          64.76
# 2     Checkout      3524            2            35.24           0.00
# 3     Purchase      1080            3            10.80          69.35

# %% [raw]
# ## Visualization

# %%
## Create Comprehensive funnel Visualization
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=(
        "Funnel Conversion Rates",
        "Stage-to-Stage Drop-off",
        "Revenue by Funnel Stage",
        "Session Duration by Stage"
    )
)

# Funnel conversion rates
fig.add_trace(
    go.Bar(
        x=funnel_df["Stage"],
        y=funnel_df["Sessions"],
        text=funnel_df["Sessions"],
        textposition="auto",
        name="Sessions",
        marker_color="lightblue"
    ),
    row=1, col=1
)

# Drop-Off Rates
fig.add_trace(
    go.Scatter(
        x=funnel_df["Stage"],
        y=funnel_df["Drop_Off_Rate"],
        mode="lines+markers+text",
        text=funnel_df["Drop_Off_Rate"],
        textposition="top center",
        name="Drop-Off Rate (%)",
        line=dict(color="red", width=3)
    ),
    row=1, col=2
)

# Revenue by Stage
revenue_by_stage = session_summary.groupby("Max_Funnel_Stage")["Revenue"].sum().reset_index()

fig.add_trace(
    go.Bar(
        x=revenue_by_stage["Max_Funnel_Stage"],
        y=revenue_by_stage["Revenue"],
        text=[f'${x:,.0f}' for x in revenue_by_stage["Revenue"]],
        textposition="auto",
        name="Revenue",
        marker_color="green"
    ),
    row=2, col=1
)

# Session duration by stage
duration_by_stage = session_summary.groupby("Max_Funnel_Stage")["Session_Duration_Min"].mean().reset_index()

fig.add_trace(
    go.Bar(
        x=duration_by_stage["Max_Funnel_Stage"],
        y=duration_by_stage["Session_Duration_Min"],
        text=duration_by_stage["Session_Duration_Min"].round(2),
        textposition="auto",
        name="Avg Session Duration (min)",
        marker_color="orange"
    ),
    row=2, col=2
)

fig.update_layout(
    height=800,
    title_text="Comprehensive Funnel Analysis Dashboard",
    showlegend=True
)

fig.show()
